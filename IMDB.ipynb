# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyanshu45132/IMDB_Movie_Analysis/blob/main/IMDB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/IMDB-Movie-Data (1).csv')

# %%
df.head(2)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
#
#                                          Description      Director  \
# 0  A group of intergalactic criminals are forced ...    James Gunn
# 1  Following clues to the origin of mankind, a te...  Ridley Scott
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
#
#    Rating   Votes  Revenue (Millions)  Metascore
# 0     8.1  757074              333.13       76.0
# 1     7.0  485820              126.46       65.0

# %%
df.tail(2)
# Out:
#      Rank         Title                  Genre  \
# 998   999  Search Party       Adventure,Comedy
# 999  1000    Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 998  Adam Pally, T.J. Miller, Thomas Middleditch,Sh...  2014
# 999  Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...  2016
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 998                 93     5.6   4881                 NaN       22.0
# 999                 87     5.3  12435               19.64       11.0

# %%
print("No. of rows",df.shape[0])
print("No. of column",df.shape[1])
# Out:
# No. of rows 1000
# No. of column 12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
df.describe(include='all')
# Out:
#                Rank     Title                    Genre  \
# count   1000.000000      1000                     1000
# unique          NaN       999                      207
# top             NaN  The Host  Action,Adventure,Sci-Fi
# freq            NaN         2                       50
# mean     500.500000       NaN                      NaN
# std      288.819436       NaN                      NaN
# min        1.000000       NaN                      NaN
# 25%      250.750000       NaN                      NaN
# 50%      500.500000       NaN                      NaN
# 75%      750.250000       NaN                      NaN
# max     1000.000000       NaN                      NaN
#
#                                               Description      Director  \
# count                                                1000          1000
# unique                                               1000           644
# top     A group of intergalactic criminals are forced ...  Ridley Scott
# ...

# %%
df.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
df.fillna('0',inplace=True)
# Out:
# <ipython-input-71-1c9a566ccb49>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna('0',inplace=True)

# %%
df.isnull().sum()
# Out:
# Rank                  0
# Title                 0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df['Runtime (Minutes)']>=180]['Title']
# Out:
# 82     The Wolf of Wall Street
# 88           The Hateful Eight
# 311             La vie d'Adèle
# 828                 Grindhouse
# 965              Inland Empire
# Name: Title, dtype: object

# %%
df.groupby('Year')['Votes'].mean().sort_values(ascending=False)
# Out:
# Year
# 2012    285226.093750
# 2008    275505.384615
# 2006    269289.954545
# 2009    255780.647059
# 2010    252782.316667
# 2007    244331.037736
# 2011    240790.301587
# 2013    219049.648352
# 2014    203930.224490
# 2015    115726.220472
# 2016     48591.754209
# Name: Votes, dtype: float64

# %%
sns.barplot(x='Year',y='Votes',data=df)
# Out:
# <Axes: xlabel='Year', ylabel='Votes'>

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df['Revenue (Millions)'].dtype
# Out:
# dtype('O')

# %%
df['Revenue']=df['Revenue (Millions)'].astype(float)

# %%
df.groupby('Year')['Revenue'].mean().sort_values(ascending=False)
# Out:
# Year
# 2012    107.973281
# 2009    103.769804
# 2010     99.827500
# 2008     97.177308
# 2011     86.221587
# 2013     84.249670
# 2006     82.374091
# 2014     81.606122
# 2007     81.249623
# 2015     69.717480
# 2016     37.749663
# Name: Revenue, dtype: float64

# %%
sns.barplot(x='Year',y='Revenue',data=df)
# Out:
# <Axes: xlabel='Year', ylabel='Revenue'>

# %%
df.groupby('Director')['Rating'].mean().sort_values(ascending=False)
# Out:
# Director
# Nitesh Tiwari        8.80
# Christopher Nolan    8.68
# Olivier Nakache      8.60
# Makoto Shinkai       8.60
# Aamir Khan           8.50
#                      ...
# Micheal Bafaro       3.50
# Jonathan Holbrook    3.20
# Shawn Burkett        2.70
# James Wong           2.70
# Jason Friedberg      1.90
# Name: Rating, Length: 644, dtype: float64

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore', 'Revenue'],
#       dtype='object')

# %%
df.groupby('Title')['Runtime (Minutes)'].max().sort_values(ascending=False).head(10)
# Out:
# Title
# Grindhouse                                  191
# The Hateful Eight                           187
# Inland Empire                               180
# The Wolf of Wall Street                     180
# La vie d'Adèle                              180
# Cloud Atlas                                 172
# 3 Idiots                                    170
# Interstellar                                169
# Pirates of the Caribbean: At World's End    169
# The Hobbit: An Unexpected Journey           169
# Name: Runtime (Minutes), dtype: int64

# %%
index=df.groupby('Title')['Runtime (Minutes)'].max().sort_values(ascending=False).head(10)

# %%
index_df=index.reset_index()

# %%
sns.barplot(x='Runtime (Minutes)',y='Title',data=index_df,palette='rocket')
# Out:
# <ipython-input-87-5093b3b6ea8a>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Runtime (Minutes)',y='Title',data=index_df,palette='rocket')
# <Axes: xlabel='Runtime (Minutes)', ylabel='Title'>

# %%
df['Year'].value_counts()
# Out:
# Year
# 2016    297
# 2015    127
# 2014     98
# 2013     91
# 2012     64
# 2011     63
# 2010     60
# 2007     53
# 2008     52
# 2009     51
# 2006     44
# Name: count, dtype: int64

# %%
sns.countplot(x='Year',data=df,palette='rocket')
# Out:
# <ipython-input-89-c8b3d76bba43>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Year',data=df,palette='rocket')
# <Axes: xlabel='Year', ylabel='count'>

# %%
df.groupby('Title')['Revenue'].max().sort_values(ascending=False).head(1)
# Out:
# Title
# Star Wars: Episode VII - The Force Awakens    936.63
# Name: Revenue, dtype: float64

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore', 'Revenue'],
#       dtype='object')

# %%
rated=df.sort_values('Rating',ascending=False)

# %%
rated[['Title','Rating','Director']].head(10)
# Out:
#                 Title  Rating           Director
# 54    The Dark Knight     9.0  Christopher Nolan
# 80          Inception     8.8  Christopher Nolan
# 117            Dangal     8.8      Nitesh Tiwari
# 36       Interstellar     8.6  Christopher Nolan
# 96      Kimi no na wa     8.6     Makoto Shinkai
# 249  The Intouchables     8.6    Olivier Nakache
# 133          Whiplash     8.5    Damien Chazelle
# 64       The Prestige     8.5  Christopher Nolan
# 99       The Departed     8.5    Martin Scorsese
# 991  Taare Zameen Par     8.5         Aamir Khan

# %%
plot=df.sort_values('Rating',ascending=False).head(10)

# %%
sns.barplot(x='Rating',y='Title',data=plot)
# Out:
# <Axes: xlabel='Rating', ylabel='Title'>

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore', 'Revenue'],
#       dtype='object')

# %%
df.groupby('Title')['Revenue'].max().sort_values(ascending=False).head(10)
# Out:
# Title
# Star Wars: Episode VII - The Force Awakens    936.63
# Avatar                                        760.51
# Jurassic World                                652.18
# The Avengers                                  623.28
# The Dark Knight                               533.32
# Rogue One                                     532.17
# Finding Dory                                  486.29
# Avengers: Age of Ultron                       458.99
# The Dark Knight Rises                         448.13
# The Hunger Games: Catching Fire               424.65
# Name: Revenue, dtype: float64

# %%
graph=df.groupby('Title')['Revenue'].max().sort_values(ascending=False).head(10).reset_index()

# %%
sns.barplot(x='Revenue',y='Title',data=graph)
# Out:
# <Axes: xlabel='Revenue', ylabel='Title'>

# %%
df.groupby ('Year')['Rating'].mean().sort_values(ascending=False)
# Out:
# Year
# 2007    7.133962
# 2006    7.125000
# 2009    6.960784
# 2012    6.925000
# 2011    6.838095
# 2014    6.837755
# 2010    6.826667
# 2013    6.812088
# 2008    6.784615
# 2015    6.602362
# 2016    6.436700
# Name: Rating, dtype: float64

# %%
graph2=df.groupby ('Year')['Rating'].mean().sort_values(ascending=False).reset_index()

# %%
sns.barplot(x='Year',y='Rating',data=graph2,palette='rocket')
# Out:
# <ipython-input-102-564cedd1dd53>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Year',y='Rating',data=graph2,palette='rocket')
# <Axes: xlabel='Year', ylabel='Rating'>

# %%
df.groupby('Rating')['Revenue'].mean().sort_values(ascending=False)
# Out:
# Rating
# 9.0    533.320000
# 4.1    166.150000
# 8.1    161.986923
# 8.8    151.860000
# 8.3    140.950000
# 8.0    133.713684
# 7.8    119.674000
# 7.9    113.978696
# 4.9    110.604286
# 8.5    109.858333
# 7.6    100.502593
# 8.4     98.282500
# 7.4     97.249394
# 7.0     87.824565
# 7.7     83.630370
# 7.5     83.587143
# 7.2     83.331190
# 8.2     79.208000
# 6.7     78.507292
# 6.2     73.385946
# 7.3     69.845238
# 8.6     68.616667
# 6.6     68.013095
# 7.1     64.980962
# 6.0     63.590000
# 6.4     63.526286
# 5.5     62.512857
# 6.5     57.026500
# 6.8     51.106486
# 6.3     47.842727
# 5.8     46.739615
# 6.9     46.218710
# 5.2     45.980000
# 6.1     45.442903
# 5.9     42.386316
# 4.3     40.067500
# 5.4     37.492500
# 5.3     37.025000
# 5.7     32.065238
# 3.9     31.820000
# 5.6     28.121176
# 4.0     20.760000
# 5.1     16.560000
# 5.0     16.127500
# 4.7     15.616667
# 1.9     14.170000
# 4.6      9.208000
# 4.8      8.582500
# 2.7      4.675000
# ...

# %%
sns.scatterplot(x='Rating',y='Revenue',data=df)
# Out:
# <Axes: xlabel='Rating', ylabel='Revenue'>

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore', 'Revenue'],
#       dtype='object')

# %%
def rating(rating):
  if rating>=7.5:
    return 'Excellent'
  elif rating>=5.5:
    return 'Good'
  else:
    return 'Bad'

# %%
df['Rating_Category']=df['Rating'].apply(rating)

# %%
df.head(2)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
#
#                                          Description      Director  \
# 0  A group of intergalactic criminals are forced ...    James Gunn
# 1  Following clues to the origin of mankind, a te...  Ridley Scott
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
#
#    Rating   Votes Revenue (Millions) Metascore  Revenue Rating_Category
# 0     8.1  757074             333.13      76.0   333.13       Excellent
# 1     7.0  485820             126.46      65.0   126.46            Good

# %%
sns.countplot(x='Rating_Category',data=df,palette='rocket')
# Out:
# <ipython-input-110-ebce4648dba1>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Rating_Category',data=df,palette='rocket')
# <Axes: xlabel='Rating_Category', ylabel='count'>

# %%
df['Genre'].str.contains('Action').sum()
# Out:
# 303
